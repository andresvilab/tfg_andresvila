# %%
import tensorflow as tf
import tensorflow.keras as K
import pandas as pd
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import metrics
# Out:
# 2024-06-21 07:15:47.869021: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-21 07:15:47.871974: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-21 07:15:47.914273: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-21 07:15:47.915563: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-21 07:15:48.650125: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
vista = 'CC' ## 'CC' o 'MLO'

# %%
def preprocess_data(X, Y):
    """
    Pre-processes the data for the model
        - X is a numpy.ndarray of shape (m, 1024, 1024, 3) containing
         the mammography, where m is the number of data points
        - Y is a numpy.ndarray of shape (m,) containing
         the Bi-Rads labels for X
    Returns:
        - X_p is a numpy.ndarray containing the preprocessed X
        - Y_p is a numpy.ndarray containing the preprocessed Y
    """
    X_p = K.applications.densenet.preprocess_input(X)

    Y_p = K.utils.to_categorical(Y, 3)

    return X_p, Y_p

# %%
df_INbreast_train = pd.read_pickle('/workspace/container_0/andres/data/df_INbreast_train.pkl')
df_INbreast_val = pd.read_pickle('/workspace/container_0/andres/data/df_INbreast_val.pkl')

if vista == 'CC':
    df_INbreast_train = df_INbreast_train.drop(columns = ['MLO Image']).rename(columns = {'CC Image': 'Image'})
    df_INbreast_val = df_INbreast_val.drop(columns = ['MLO Image']).rename(columns = {'CC Image': 'Image'})
elif vista == 'MLO':
    df_INbreast_train = df_INbreast_train.drop(columns = ['CC Image']).rename(columns = {'MLO Image': 'Image'})
    df_INbreast_val = df_INbreast_val.drop(columns = ['CC Image']).rename(columns = {'MLO Image': 'Image'})

# %%
dict_valores = {'benigno': 0, 'seguimiento': 1, 'maligno': 2}
Y_traintest = np.array(df_INbreast_train['Bi-Rads'].map(dict_valores).tolist())
X_traintest = np.array(df_INbreast_train['Image'].tolist())
Y_val = np.array(df_INbreast_val['Bi-Rads'].map(dict_valores).tolist())
X_val = np.array(df_INbreast_val['Image'].tolist())
X_val, Y_val = preprocess_data(X_val, Y_val)
del df_INbreast_train
del df_INbreast_val

# %%
def DenseNet169_1Rama(vista, input_dim = 512, rand_seed = 13, learning_rate = 0.0001, momentum = 0.9):
    """
    Define the DenseNet architecture and compile the model
        - vista is a mammogram view we want to train
        - input_dim is the size of the mammogram in pixels
        - rand_seed is a random seed number used during the fc layer initialization
        - learning_rate is the learning rate used during the training
        - momentum is the parameters that defines the momentun for the SGD optimizer
    Returns:
        - model_1rama is the output compiled DenseNet model
    """
    # Definimos la architectura del modelo
    densenet = K.applications.DenseNet169(
        include_top = False,
        weights = "imagenet",
        input_tensor = None,
        input_shape = (256, 256, 3),
        pooling = 'avg'
    )

    densenet.trainable = True

    # Entrenaremos solo el bloque de capas conv5, las demas las dejamos con los pesos preestablecidos de la DenseNet121
    for layer in densenet.layers:
        if 'conv5' in layer.name:
            layer.trainable = True
        else:
            layer.trainable = False

    # Deefinimos el tamaño de las imágenes de entrada.
    input_img = K.Input(shape = (input_dim, input_dim, 3))
    # Lambda que ajustará la imagenes a un tamaño de  256x256
    preprocess = K.layers.Lambda(lambda x: tf.image.resize(x, (256, 256)), name = 'resize_' + vista)(input_img)

    initializer = K.initializers.he_normal(seed = rand_seed)

    fc_layer = densenet(inputs = preprocess)

    fc_layer = K.layers.Dense(units = 3,
                              activation = 'softmax',
                              kernel_initializer = initializer
                              )(fc_layer)

    model_1rama = K.models.Model(inputs = input_img, outputs = fc_layer)

    # Compile the model
    opt = K.optimizers.SGD(learning_rate = learning_rate, momentum = momentum)

    model_1rama.compile(loss = 'categorical_crossentropy',
                        optimizer = opt,
                        metrics = ['accuracy'])

    return model_1rama

# %%
DenseNet169_1Rama(vista).summary()
# Out:
# 2024-06-21 07:15:55.259983: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-21 07:15:55.260832: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 2s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 512, 512, 3)]     0
#
#  resize_CC (Lambda)          (None, 256, 256, 3)       0
#
#  densenet169 (Functional)    (None, 1664)              12642880
#
#  dense (Dense)               (None, 3)                 4995
#
# =================================================================
# Total params: 12647875 (48.25 MB)
# Trainable params: 5918595 (22.58 MB)
# Non-trainable params: 6729280 (25.67 MB)
# _________________________________________________________________

# %%
def part_traintest(X_traintest, Y_traintest, rand_seed = 13, frac_test = .2/.8):
    """
    Function that makes a partition for training and testing from the original dataset
        - X_traintest is the array of images from the original dataset
        - Y_traintest is the array of labels from the original dataset
        - rand_seed is a random seed number used during the sampling
        - frac_test is the fraction of cases used in the test subset
    Returns:
        - X_train is the train array of images
        - Y_train is the train array of labels
        - X_test is the test array of images
        - Y_test is the test array of labels
    """
    np.random.seed(rand_seed)
    index_test = np.array([], dtype = 'int')

    for i in np.unique(Y_traintest):
        index_test = np.append(index_test,
                               np.random.choice(list(np.where(Y_traintest == i)[0]), size = int(np.where(Y_traintest == i)[0].shape[0]*frac_test), replace = False))

    index_test = [int(x) for x in index_test]
    print(index_test)
    X_train = np.delete(X_traintest, index_test, axis = 0)

    Y_train = np.delete(Y_traintest, index_test)
    X_test = np.take(X_traintest, index_test, axis = 0)
    Y_test = np.take(Y_traintest, index_test)
#     print(X_train)
#     print(Y_train)
#     print(Y_traintest)
    X_train, Y_train = preprocess_data(X_train, Y_train)
    X_test, Y_test = preprocess_data(X_test, Y_test)


    return X_train, Y_train, X_test, Y_test

# %%
batch_size = 16
no_epochs = 300
input_dim = X_traintest.shape[1]
rand_seed = 2021
n_folds = 3
frac_test = .2/.8

# %%
label, counts = np.unique(Y_traintest, return_counts = True)
class_weight = {}
for lab, con in zip(label, counts):
  class_weight.update({lab: round(max(counts)/con, 2)})

# %%
early_stopping = EarlyStopping(patience = 20, restore_best_weights = True)
reduce_lr = ReduceLROnPlateau(factor = 0.5, patience = 5)

# %%
learn_rate = [0.01, 0.001, 0.0001]
momentum = [0, 0.5, 0.9]

tot_comb = len(learn_rate) * len(momentum)
glob_param = np.empty([tot_comb, 2])

history_list = []
scores_glob_array = np.empty([tot_comb, n_folds, 2])

import itertools

for idx, x in enumerate(itertools.product(learn_rate, momentum)):
    learn_rate = x[0]
    momentum = x[1]

    # Generate a print
    print('------------------------------------------------------------------------')
    print(f'Training for combination {idx + 1}/{tot_comb} ...')
    print(f'Learning rate = {learn_rate}')
    print(f'Momentum = {momentum}')
    print('------------------------------------------------------------------------')

    history_array = np.array([])
    scores_array = np.empty([n_folds, 2])

    glob_param[idx, 0] = learn_rate
    glob_param[idx, 1] = momentum

    for fold in range(n_folds):
        # Generate a print
        print('------------------------------------------------------------------------')
        print(f'Training for fold {fold + 1}/{n_folds} ...')
        print('------------------------------------------------------------------------')

        # Generate the fold sample for train-test
        X_train, Y_train, X_test, Y_test = part_traintest(X_traintest, Y_traintest, rand_seed + fold, frac_test)

        # Define the model architecture
        model_1rama = DenseNet169_1Rama(vista, input_dim, rand_seed, learn_rate, momentum)

        # Fit data to model
        history = model_1rama.fit(X_train, Y_train,
                                  batch_size = batch_size,
                                  epochs = no_epochs,
                                  validation_data = (X_test, Y_test),
                                  class_weight = class_weight,
                                  verbose = 1,
                                  callbacks = [early_stopping, reduce_lr])

        # Generate generalization metrics
        scores_array[fold, :] = model_1rama.evaluate(X_val, Y_val, verbose = 0)
        print('------------------------------------------------------------------------')
        print(f'Score for fold {fold + 1}: {model_1rama.metrics_names[0]} of {round(scores_array[fold, 0], 2)}; {model_1rama.metrics_names[1]} of {round(scores_array[fold, 1]*100, 2)}%')
        print('------------------------------------------------------------------------')
        print('')

        # Append history callback into array
        history_array = np.append(history_array, [history])

    # == Provide average scores ==
    print('------------------------------------------------------------------------')
    print('Score per fold')
    for i in range(0, scores_array.shape[0]):
        print('------------------------------------------------------------------------')
        print(f'> Fold {i + 1} - Loss: {round(scores_array[i, 0], 2)} - Accuracy: {round(scores_array[i, 1], 2)}%')
    print('------------------------------------------------------------------------')
    print(f'Average scores for all folds (LR = {learn_rate}, mtm = {momentum}):')
    print(f'> Accuracy: {round(np.mean(scores_array[:, 1]), 2)} (+- {round(np.std(scores_array[:, 1]), 2)})')
    print(f'> Loss: {round(np.mean(scores_array[:, 0]), 2)} (+- {round(np.std(scores_array[:, 0]), 2)})')
    print('------------------------------------------------------------------------')
    print('')
    print('')

    idx_best_hist = np.argmax(scores_array[:, 1])
    history_list.append(history_array[idx_best_hist])

    scores_glob_array[idx, :, :] = scores_array
# Out:
# ------------------------------------------------------------------------
# Training for combination 1/9 ...
# Learning rate = 0.01
# Momentum = 0
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1/3 ...
# ------------------------------------------------------------------------
# [21, 60, 9, 48, 31, 16, 47, 51, 143, 69, 116, 83, 38, 67, 41, 11, 85, 144, 63, 156, 115, 126, 119, 153, 102, 113, 147, 106, 159, 7, 187, 185, 196, 186, 201, 206, 179, 175, 111, 164, 160, 182, 71, 138, 66, 50, 1, 205, 45, 53, 62, 105]
# Epoch 1/300
# 10/10 [==============================] - 24s 2s/step - loss: 2.2195 - accuracy: 0.4051 - val_loss: 1.8560 - val_accuracy: 0.0769 - lr: 0.0100
# Epoch 2/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.5149 - accuracy: 0.4684 - val_loss: 0.9343 - val_accuracy: 0.3846 - lr: 0.0100
# Epoch 3/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.1101 - accuracy: 0.6646 - val_loss: 0.8352 - val_accuracy: 0.4615 - lr: 0.0100
# Epoch 4/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.5610 - accuracy: 0.8734 - val_loss: 0.9877 - val_accuracy: 0.5385 - lr: 0.0100
# Epoch 5/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.2257 - accuracy: 0.9747 - val_loss: 0.8359 - val_accuracy: 0.6154 - lr: 0.0100
# Epoch 6/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.1208 - accuracy: 0.9873 - val_loss: 0.9008 - val_accuracy: 0.5769 - lr: 0.0100
# Epoch 7/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0578 - accuracy: 1.0000 - val_loss: 0.8203 - val_accuracy: 0.5962 - lr: 0.0100
# Epoch 8/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0460 - accuracy: 1.0000 - val_loss: 1.0815 - val_accuracy: 0.5192 - lr: 0.0100
# Epoch 9/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0346 - accuracy: 1.0000 - val_loss: 1.0327 - val_accuracy: 0.5577 - lr: 0.0100
# Epoch 10/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 1.1183 - val_accuracy: 0.6346 - lr: 0.0100
# Epoch 11/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 1.0417 - val_accuracy: 0.6154 - lr: 0.0100
# Epoch 12/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.2327 - accuracy: 0.8987 - val_loss: 0.9444 - val_accuracy: 0.6538 - lr: 0.0100
# Epoch 13/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0406 - accuracy: 0.9873 - val_loss: 0.9592 - val_accuracy: 0.7115 - lr: 0.0050
# Epoch 14/300
# 10/10 [==============================] - 15s 1s/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 1.0969 - val_accuracy: 0.6731 - lr: 0.0050
# Epoch 15/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 1.0599 - val_accuracy: 0.6538 - lr: 0.0050
# Epoch 16/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 1.1157 - val_accuracy: 0.6731 - lr: 0.0050
# Epoch 17/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.1359 - val_accuracy: 0.6538 - lr: 0.0050
# Epoch 18/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.1466 - val_accuracy: 0.6538 - lr: 0.0025
# Epoch 19/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.1518 - val_accuracy: 0.6538 - lr: 0.0025
# Epoch 20/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.1579 - val_accuracy: 0.6731 - lr: 0.0025
# Epoch 21/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.1568 - val_accuracy: 0.6731 - lr: 0.0025
# Epoch 22/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.1633 - val_accuracy: 0.6731 - lr: 0.0025
# Epoch 23/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 1.1770 - val_accuracy: 0.6538 - lr: 0.0012
# Epoch 24/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.1666 - val_accuracy: 0.6731 - lr: 0.0012
# Epoch 25/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.1664 - val_accuracy: 0.6731 - lr: 0.0012
# Epoch 26/300
# 10/10 [==============================] - 11s 1s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.1693 - val_accuracy: 0.6731 - lr: 0.0012
# Epoch 27/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.1738 - val_accuracy: 0.6731 - lr: 0.0012
# ------------------------------------------------------------------------
# Score for fold 1: loss of 0.82; accuracy of 65.38%
# ------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Training for fold 2/3 ...
# ------------------------------------------------------------------------
# [85, 63, 129, 31, 156, 158, 48, 139, 121, 13, 108, 140, 65, 95, 150, 128, 103, 26, 56, 10, 86, 153, 96, 75, 18, 151, 98, 41, 185, 0, 57, 187, 183, 101, 173, 130, 53, 200, 171, 189, 66, 43, 142, 12, 133, 105, 94, 62, 176, 191, 197, 190]
# Epoch 1/300
# 10/10 [==============================] - 26s 2s/step - loss: 2.4444 - accuracy: 0.3354 - val_loss: 1.2267 - val_accuracy: 0.2115 - lr: 0.0100
# Epoch 2/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.3776 - accuracy: 0.5570 - val_loss: 1.9165 - val_accuracy: 0.0769 - lr: 0.0100
# Epoch 3/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.0113 - accuracy: 0.6772 - val_loss: 0.9342 - val_accuracy: 0.5577 - lr: 0.0100
# Epoch 4/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.4843 - accuracy: 0.8671 - val_loss: 1.0709 - val_accuracy: 0.5385 - lr: 0.0100
# Epoch 5/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.3126 - accuracy: 0.9177 - val_loss: 1.2508 - val_accuracy: 0.5769 - lr: 0.0100
# Epoch 6/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.1795 - accuracy: 0.9747 - val_loss: 0.8639 - val_accuracy: 0.6154 - lr: 0.0100
# Epoch 7/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0931 - accuracy: 0.9937 - val_loss: 1.2413 - val_accuracy: 0.5577 - lr: 0.0100
# Epoch 8/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0714 - accuracy: 0.9937 - val_loss: 1.3625 - val_accuracy: 0.5577 - lr: 0.0100
# Epoch 9/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 1.4876 - val_accuracy: 0.5577 - lr: 0.0100
# Epoch 10/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 1.7231 - val_accuracy: 0.5385 - lr: 0.0100
# Epoch 11/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 1.7736 - val_accuracy: 0.5577 - lr: 0.0100
# Epoch 12/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 1.8592 - val_accuracy: 0.5577 - lr: 0.0050
# Epoch 13/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.7918 - val_accuracy: 0.5962 - lr: 0.0050
# Epoch 14/300
# 10/10 [==============================] - 11s 1s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.7524 - val_accuracy: 0.6154 - lr: 0.0050
# Epoch 15/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.7485 - val_accuracy: 0.6154 - lr: 0.0050
# Epoch 16/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.7081 - val_accuracy: 0.6154 - lr: 0.0050
# Epoch 17/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.6514 - val_accuracy: 0.6346 - lr: 0.0025
# Epoch 18/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.6025 - val_accuracy: 0.6346 - lr: 0.0025
# Epoch 19/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.5702 - val_accuracy: 0.6346 - lr: 0.0025
# Epoch 20/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.5407 - val_accuracy: 0.6346 - lr: 0.0025
# Epoch 21/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.4954 - val_accuracy: 0.6346 - lr: 0.0025
# Epoch 22/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.4529 - val_accuracy: 0.6346 - lr: 0.0012
# Epoch 23/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.3889 - val_accuracy: 0.6346 - lr: 0.0012
# Epoch 24/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.3767 - val_accuracy: 0.6346 - lr: 0.0012
# Epoch 25/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.3210 - val_accuracy: 0.6154 - lr: 0.0012
# Epoch 26/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.3014 - val_accuracy: 0.6154 - lr: 0.0012
# ------------------------------------------------------------------------
# Score for fold 2: loss of 0.84; accuracy of 63.46%
# ------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Training for fold 3/3 ...
# ------------------------------------------------------------------------
# [25, 60, 84, 152, 17, 120, 20, 136, 2, 51, 103, 21, 148, 131, 143, 37, 89, 83, 33, 151, 104, 29, 11, 86, 32, 106, 16, 41, 185, 187, 7, 5, 62, 181, 3, 182, 161, 4, 192, 127, 194, 45, 179, 24, 70, 195, 193, 97, 155, 164, 40, 101]
# Epoch 1/300
# 10/10 [==============================] - 26s 2s/step - loss: 2.5884 - accuracy: 0.3038 - val_loss: 1.0245 - val_accuracy: 0.5385 - lr: 0.0100
# Epoch 2/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.4677 - accuracy: 0.5253 - val_loss: 0.8686 - val_accuracy: 0.6731 - lr: 0.0100
# Epoch 3/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.1939 - accuracy: 0.6709 - val_loss: 0.8931 - val_accuracy: 0.4231 - lr: 0.0100
# Epoch 4/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.9461 - accuracy: 0.6456 - val_loss: 0.7710 - val_accuracy: 0.6346 - lr: 0.0100
# Epoch 5/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.3753 - accuracy: 0.9304 - val_loss: 1.1783 - val_accuracy: 0.5577 - lr: 0.0100
# Epoch 6/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.2462 - accuracy: 0.9494 - val_loss: 0.9873 - val_accuracy: 0.5769 - lr: 0.0100
# Epoch 7/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.1307 - accuracy: 0.9937 - val_loss: 1.0917 - val_accuracy: 0.5769 - lr: 0.0100
# Epoch 8/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0910 - accuracy: 0.9937 - val_loss: 0.8841 - val_accuracy: 0.6154 - lr: 0.0100
# Epoch 9/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.8900 - val_accuracy: 0.6346 - lr: 0.0100
# Epoch 10/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0407 - accuracy: 1.0000 - val_loss: 0.8981 - val_accuracy: 0.6154 - lr: 0.0050
# Epoch 11/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 1.0077 - val_accuracy: 0.6731 - lr: 0.0050
# Epoch 12/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 1.0507 - val_accuracy: 0.6923 - lr: 0.0050
# Epoch 13/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.9961 - val_accuracy: 0.6923 - lr: 0.0050
# Epoch 14/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 1.0533 - val_accuracy: 0.6923 - lr: 0.0050
# Epoch 15/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 1.0159 - val_accuracy: 0.7115 - lr: 0.0025
# Epoch 16/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.9959 - val_accuracy: 0.7115 - lr: 0.0025
# Epoch 17/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.9744 - val_accuracy: 0.7115 - lr: 0.0025
# Epoch 18/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.9493 - val_accuracy: 0.7308 - lr: 0.0025
# Epoch 19/300
# 10/10 [==============================] - 11s 1s/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.9125 - val_accuracy: 0.7308 - lr: 0.0025
# Epoch 20/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.9030 - val_accuracy: 0.7308 - lr: 0.0012
# Epoch 21/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.8851 - val_accuracy: 0.7308 - lr: 0.0012
# Epoch 22/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.8711 - val_accuracy: 0.7115 - lr: 0.0012
# Epoch 23/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.8616 - val_accuracy: 0.7115 - lr: 0.0012
# Epoch 24/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.8443 - val_accuracy: 0.7500 - lr: 0.0012
# ------------------------------------------------------------------------
# Score for fold 3: loss of 0.84; accuracy of 67.31%
# ------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.82 - Accuracy: 0.65%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.84 - Accuracy: 0.63%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.84 - Accuracy: 0.67%
# ------------------------------------------------------------------------
# Average scores for all folds (LR = 0.01, mtm = 0):
# > Accuracy: 0.65 (+- 0.02)
# > Loss: 0.83 (+- 0.01)
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# Training for combination 2/9 ...
# Learning rate = 0.01
# Momentum = 0.5
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1/3 ...
# ------------------------------------------------------------------------
# [21, 60, 9, 48, 31, 16, 47, 51, 143, 69, 116, 83, 38, 67, 41, 11, 85, 144, 63, 156, 115, 126, 119, 153, 102, 113, 147, 106, 159, 7, 187, 185, 196, 186, 201, 206, 179, 175, 111, 164, 160, 182, 71, 138, 66, 50, 1, 205, 45, 53, 62, 105]
# Epoch 1/300
# 10/10 [==============================] - 25s 2s/step - loss: 2.1021 - accuracy: 0.3608 - val_loss: 1.2911 - val_accuracy: 0.4231 - lr: 0.0100
# Epoch 2/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.1887 - accuracy: 0.6392 - val_loss: 0.8793 - val_accuracy: 0.3846 - lr: 0.0100
# Epoch 3/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.7169 - accuracy: 0.7785 - val_loss: 0.7656 - val_accuracy: 0.6154 - lr: 0.0100
# Epoch 4/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.3076 - accuracy: 0.9304 - val_loss: 0.7644 - val_accuracy: 0.6538 - lr: 0.0100
# Epoch 5/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0893 - accuracy: 0.9810 - val_loss: 0.7960 - val_accuracy: 0.6731 - lr: 0.0100
# Epoch 6/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.8056 - val_accuracy: 0.6538 - lr: 0.0100
# Epoch 7/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.9269 - val_accuracy: 0.6538 - lr: 0.0100
# Epoch 8/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.9531 - val_accuracy: 0.6538 - lr: 0.0100
# Epoch 9/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.9605 - val_accuracy: 0.6731 - lr: 0.0100
# Epoch 10/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.0863 - val_accuracy: 0.6538 - lr: 0.0050
# Epoch 11/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.9980 - val_accuracy: 0.6923 - lr: 0.0050
# Epoch 12/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.9775 - val_accuracy: 0.6923 - lr: 0.0050
# Epoch 13/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.9654 - val_accuracy: 0.7115 - lr: 0.0050
# Epoch 14/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.9704 - val_accuracy: 0.7115 - lr: 0.0050
# Epoch 15/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.9082 - val_accuracy: 0.7500 - lr: 0.0025
# Epoch 16/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.9077 - val_accuracy: 0.7692 - lr: 0.0025
# Epoch 17/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.9091 - val_accuracy: 0.7692 - lr: 0.0025
# Epoch 18/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.9235 - val_accuracy: 0.7500 - lr: 0.0025
# Epoch 19/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9223 - val_accuracy: 0.7308 - lr: 0.0025
# Epoch 20/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9246 - val_accuracy: 0.7308 - lr: 0.0012
# Epoch 21/300
# 10/10 [==============================] - 11s 1s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.9228 - val_accuracy: 0.7308 - lr: 0.0012
# Epoch 22/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.9241 - val_accuracy: 0.7308 - lr: 0.0012
# Epoch 23/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.9268 - val_accuracy: 0.7500 - lr: 0.0012
# Epoch 24/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.9271 - val_accuracy: 0.7500 - lr: 0.0012
# ------------------------------------------------------------------------
# Score for fold 1: loss of 0.8; accuracy of 65.38%
# ------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Training for fold 2/3 ...
# ------------------------------------------------------------------------
# [85, 63, 129, 31, 156, 158, 48, 139, 121, 13, 108, 140, 65, 95, 150, 128, 103, 26, 56, 10, 86, 153, 96, 75, 18, 151, 98, 41, 185, 0, 57, 187, 183, 101, 173, 130, 53, 200, 171, 189, 66, 43, 142, 12, 133, 105, 94, 62, 176, 191, 197, 190]
# Epoch 1/300
# 10/10 [==============================] - 26s 2s/step - loss: 2.3812 - accuracy: 0.3481 - val_loss: 1.3697 - val_accuracy: 0.0769 - lr: 0.0100
# Epoch 2/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.2698 - accuracy: 0.6962 - val_loss: 1.9724 - val_accuracy: 0.0962 - lr: 0.0100
# Epoch 3/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.0318 - accuracy: 0.6899 - val_loss: 0.8298 - val_accuracy: 0.5962 - lr: 0.0100
# Epoch 4/300
# 10/10 [==============================] - 15s 1s/step - loss: 0.4458 - accuracy: 0.8987 - val_loss: 1.2800 - val_accuracy: 0.2885 - lr: 0.0100
# Epoch 5/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.3844 - accuracy: 0.8861 - val_loss: 1.0552 - val_accuracy: 0.5769 - lr: 0.0100
# Epoch 6/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.1810 - accuracy: 0.9304 - val_loss: 2.6193 - val_accuracy: 0.5385 - lr: 0.0100
# Epoch 7/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.2700 - accuracy: 0.9177 - val_loss: 2.6944 - val_accuracy: 0.5385 - lr: 0.0100
# Epoch 8/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0830 - accuracy: 0.9810 - val_loss: 2.2315 - val_accuracy: 0.5577 - lr: 0.0100
# Epoch 9/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0761 - accuracy: 0.9873 - val_loss: 1.8535 - val_accuracy: 0.5769 - lr: 0.0050
# Epoch 10/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 2.0128 - val_accuracy: 0.5769 - lr: 0.0050
# Epoch 11/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.9195 - val_accuracy: 0.5962 - lr: 0.0050
# Epoch 12/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.8942 - val_accuracy: 0.6154 - lr: 0.0050
# Epoch 13/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.7711 - val_accuracy: 0.6538 - lr: 0.0050
# Epoch 14/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 1.7451 - val_accuracy: 0.6346 - lr: 0.0025
# Epoch 15/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.6072 - val_accuracy: 0.6346 - lr: 0.0025
# Epoch 16/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.5259 - val_accuracy: 0.6154 - lr: 0.0025
# Epoch 17/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.4664 - val_accuracy: 0.6154 - lr: 0.0025
# Epoch 18/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.3940 - val_accuracy: 0.6538 - lr: 0.0025
# Epoch 19/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0184 - accuracy: 0.9937 - val_loss: 1.1494 - val_accuracy: 0.6346 - lr: 0.0012
# Epoch 20/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 1.1265 - val_accuracy: 0.6346 - lr: 0.0012
# Epoch 21/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.1360 - val_accuracy: 0.6346 - lr: 0.0012
# Epoch 22/300
# 10/10 [==============================] - 11s 1s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.1314 - val_accuracy: 0.6538 - lr: 0.0012
# Epoch 23/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.1403 - val_accuracy: 0.6731 - lr: 0.0012
# ------------------------------------------------------------------------
# Score for fold 2: loss of 0.8; accuracy of 63.46%
# ------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Training for fold 3/3 ...
# ------------------------------------------------------------------------
# [25, 60, 84, 152, 17, 120, 20, 136, 2, 51, 103, 21, 148, 131, 143, 37, 89, 83, 33, 151, 104, 29, 11, 86, 32, 106, 16, 41, 185, 187, 7, 5, 62, 181, 3, 182, 161, 4, 192, 127, 194, 45, 179, 24, 70, 195, 193, 97, 155, 164, 40, 101]
# Epoch 1/300
# 10/10 [==============================] - 25s 2s/step - loss: 2.2328 - accuracy: 0.3924 - val_loss: 1.0618 - val_accuracy: 0.5385 - lr: 0.0100
# Epoch 2/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.5479 - accuracy: 0.4937 - val_loss: 0.7930 - val_accuracy: 0.6731 - lr: 0.0100
# Epoch 3/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.7131 - accuracy: 0.8734 - val_loss: 0.7870 - val_accuracy: 0.6923 - lr: 0.0100
# Epoch 4/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.3867 - accuracy: 0.9177 - val_loss: 2.3208 - val_accuracy: 0.3846 - lr: 0.0100
# Epoch 5/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.2524 - accuracy: 0.9430 - val_loss: 0.8873 - val_accuracy: 0.6538 - lr: 0.0100
# Epoch 6/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.1313 - accuracy: 0.9684 - val_loss: 1.3883 - val_accuracy: 0.6154 - lr: 0.0100
# Epoch 7/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0267 - accuracy: 1.0000 - val_loss: 1.5611 - val_accuracy: 0.5962 - lr: 0.0100
# Epoch 8/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.2999 - val_accuracy: 0.7308 - lr: 0.0100
# Epoch 9/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 1.2598 - val_accuracy: 0.7500 - lr: 0.0050
# Epoch 10/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.1718 - val_accuracy: 0.6731 - lr: 0.0050
# Epoch 11/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.1638 - val_accuracy: 0.6731 - lr: 0.0050
# Epoch 12/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.1952 - val_accuracy: 0.7500 - lr: 0.0050
# Epoch 13/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.1629 - val_accuracy: 0.6923 - lr: 0.0050
# Epoch 14/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.1610 - val_accuracy: 0.6923 - lr: 0.0025
# Epoch 15/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.1528 - val_accuracy: 0.6731 - lr: 0.0025
# Epoch 16/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.1431 - val_accuracy: 0.6731 - lr: 0.0025
# Epoch 17/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.1337 - val_accuracy: 0.6731 - lr: 0.0025
# Epoch 18/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.1275 - val_accuracy: 0.6731 - lr: 0.0025
# Epoch 19/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.1172 - val_accuracy: 0.6731 - lr: 0.0012
# Epoch 20/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.1106 - val_accuracy: 0.6731 - lr: 0.0012
# Epoch 21/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.1068 - val_accuracy: 0.6731 - lr: 0.0012
# Epoch 22/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.1004 - val_accuracy: 0.6731 - lr: 0.0012
# Epoch 23/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0925 - val_accuracy: 0.6731 - lr: 0.0012
# ------------------------------------------------------------------------
# Score for fold 3: loss of 0.83; accuracy of 65.38%
# ------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.8 - Accuracy: 0.65%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.8 - Accuracy: 0.63%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.83 - Accuracy: 0.65%
# ------------------------------------------------------------------------
# Average scores for all folds (LR = 0.01, mtm = 0.5):
# > Accuracy: 0.65 (+- 0.01)
# > Loss: 0.81 (+- 0.02)
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# Training for combination 3/9 ...
# Learning rate = 0.01
# Momentum = 0.9
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1/3 ...
# ------------------------------------------------------------------------
# [21, 60, 9, 48, 31, 16, 47, 51, 143, 69, 116, 83, 38, 67, 41, 11, 85, 144, 63, 156, 115, 126, 119, 153, 102, 113, 147, 106, 159, 7, 187, 185, 196, 186, 201, 206, 179, 175, 111, 164, 160, 182, 71, 138, 66, 50, 1, 205, 45, 53, 62, 105]
# Epoch 1/300
# 10/10 [==============================] - 25s 2s/step - loss: 3.0627 - accuracy: 0.3608 - val_loss: 1.3911 - val_accuracy: 0.3846 - lr: 0.0100
# Epoch 2/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.9859 - accuracy: 0.3671 - val_loss: 20.6215 - val_accuracy: 0.0769 - lr: 0.0100
# Epoch 3/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.6519 - accuracy: 0.4051 - val_loss: 10.7250 - val_accuracy: 0.0769 - lr: 0.0100
# Epoch 4/300
# 10/10 [==============================] - 12s 1s/step - loss: 1.0669 - accuracy: 0.6519 - val_loss: 5.8838 - val_accuracy: 0.3077 - lr: 0.0100
# Epoch 5/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.9054 - accuracy: 0.6835 - val_loss: 8.9488 - val_accuracy: 0.5385 - lr: 0.0100
# Epoch 6/300
# 10/10 [==============================] - 13s 1s/step - loss: 1.3989 - accuracy: 0.6646 - val_loss: 10.8264 - val_accuracy: 0.5577 - lr: 0.0100
# Epoch 7/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.7144 - accuracy: 0.7722 - val_loss: 10.4643 - val_accuracy: 0.5000 - lr: 0.0050
# Epoch 8/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.4792 - accuracy: 0.8481 - val_loss: 11.3802 - val_accuracy: 0.5769 - lr: 0.0050
# Epoch 9/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.3893 - accuracy: 0.8797 - val_loss: 12.0834 - val_accuracy: 0.5577 - lr: 0.0050
# Epoch 10/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.2334 - accuracy: 0.9114 - val_loss: 12.2341 - val_accuracy: 0.4231 - lr: 0.0050
# Epoch 11/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.2311 - accuracy: 0.9494 - val_loss: 5.6146 - val_accuracy: 0.4615 - lr: 0.0050
# Epoch 12/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.7282 - accuracy: 0.8418 - val_loss: 3.3534 - val_accuracy: 0.5577 - lr: 0.0025
# Epoch 13/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.3021 - accuracy: 0.9241 - val_loss: 29.7863 - val_accuracy: 0.2692 - lr: 0.0025
# Epoch 14/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.2251 - accuracy: 0.9241 - val_loss: 13.4741 - val_accuracy: 0.5385 - lr: 0.0025
# Epoch 15/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.3263 - accuracy: 0.9241 - val_loss: 12.9429 - val_accuracy: 0.2308 - lr: 0.0025
# Epoch 16/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.2050 - accuracy: 0.9494 - val_loss: 3.6061 - val_accuracy: 0.4808 - lr: 0.0025
# Epoch 17/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.1830 - accuracy: 0.9430 - val_loss: 2.6029 - val_accuracy: 0.5000 - lr: 0.0012
# Epoch 18/300
# 10/10 [==============================] - 15s 1s/step - loss: 0.0439 - accuracy: 1.0000 - val_loss: 2.2607 - val_accuracy: 0.5577 - lr: 0.0012
# Epoch 19/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0415 - accuracy: 1.0000 - val_loss: 1.9602 - val_accuracy: 0.5385 - lr: 0.0012
# Epoch 20/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 1.7816 - val_accuracy: 0.6154 - lr: 0.0012
# Epoch 21/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 1.7329 - val_accuracy: 0.6346 - lr: 0.0012
# ------------------------------------------------------------------------
# Score for fold 1: loss of 1.4; accuracy of 38.46%
# ------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Training for fold 2/3 ...
# ------------------------------------------------------------------------
# [85, 63, 129, 31, 156, 158, 48, 139, 121, 13, 108, 140, 65, 95, 150, 128, 103, 26, 56, 10, 86, 153, 96, 75, 18, 151, 98, 41, 185, 0, 57, 187, 183, 101, 173, 130, 53, 200, 171, 189, 66, 43, 142, 12, 133, 105, 94, 62, 176, 191, 197, 190]
# Epoch 1/300
# 10/10 [==============================] - 26s 2s/step - loss: 2.4196 - accuracy: 0.3671 - val_loss: 5.5877 - val_accuracy: 0.0769 - lr: 0.0100
# Epoch 2/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.9276 - accuracy: 0.4367 - val_loss: 1.1156 - val_accuracy: 0.4038 - lr: 0.0100
# Epoch 3/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.8455 - accuracy: 0.5316 - val_loss: 16.2865 - val_accuracy: 0.0769 - lr: 0.0100
# Epoch 4/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.1192 - accuracy: 0.6646 - val_loss: 10.6608 - val_accuracy: 0.3077 - lr: 0.0100
# Epoch 5/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.0645 - accuracy: 0.7215 - val_loss: 5.1439 - val_accuracy: 0.5192 - lr: 0.0100
# Epoch 6/300
# 10/10 [==============================] - 13s 1s/step - loss: 1.7492 - accuracy: 0.6709 - val_loss: 59.2442 - val_accuracy: 0.5385 - lr: 0.0100
# Epoch 7/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.9004 - accuracy: 0.5759 - val_loss: 37.6111 - val_accuracy: 0.4423 - lr: 0.0100
# Epoch 8/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.7542 - accuracy: 0.7278 - val_loss: 98.1981 - val_accuracy: 0.5385 - lr: 0.0050
# Epoch 9/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.8385 - accuracy: 0.8228 - val_loss: 307.1641 - val_accuracy: 0.1154 - lr: 0.0050
# Epoch 10/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.4450 - accuracy: 0.9114 - val_loss: 88.0341 - val_accuracy: 0.0962 - lr: 0.0050
# Epoch 11/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.3940 - accuracy: 0.8924 - val_loss: 17.6651 - val_accuracy: 0.5385 - lr: 0.0050
# Epoch 12/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.3493 - accuracy: 0.9241 - val_loss: 15.5072 - val_accuracy: 0.3654 - lr: 0.0050
# Epoch 13/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.1777 - accuracy: 0.9494 - val_loss: 22.0642 - val_accuracy: 0.5000 - lr: 0.0025
# Epoch 14/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.2558 - accuracy: 0.9304 - val_loss: 13.2840 - val_accuracy: 0.4231 - lr: 0.0025
# Epoch 15/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0679 - accuracy: 0.9810 - val_loss: 9.6681 - val_accuracy: 0.4423 - lr: 0.0025
# Epoch 16/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.4648 - accuracy: 0.8544 - val_loss: 6.6978 - val_accuracy: 0.5000 - lr: 0.0025
# Epoch 17/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.3085 - accuracy: 0.9114 - val_loss: 8.1090 - val_accuracy: 0.5000 - lr: 0.0025
# Epoch 18/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0833 - accuracy: 0.9747 - val_loss: 4.1952 - val_accuracy: 0.5769 - lr: 0.0012
# Epoch 19/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0566 - accuracy: 0.9873 - val_loss: 4.0151 - val_accuracy: 0.5385 - lr: 0.0012
# Epoch 20/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0246 - accuracy: 0.9937 - val_loss: 4.0982 - val_accuracy: 0.5769 - lr: 0.0012
# Epoch 21/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.0394 - accuracy: 0.9937 - val_loss: 4.0716 - val_accuracy: 0.5577 - lr: 0.0012
# Epoch 22/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 2.9638 - val_accuracy: 0.5769 - lr: 0.0012
# ------------------------------------------------------------------------
# Score for fold 2: loss of 1.08; accuracy of 34.62%
# ------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Training for fold 3/3 ...
# ------------------------------------------------------------------------
# [25, 60, 84, 152, 17, 120, 20, 136, 2, 51, 103, 21, 148, 131, 143, 37, 89, 83, 33, 151, 104, 29, 11, 86, 32, 106, 16, 41, 185, 187, 7, 5, 62, 181, 3, 182, 161, 4, 192, 127, 194, 45, 179, 24, 70, 195, 193, 97, 155, 164, 40, 101]
# Epoch 1/300
# 10/10 [==============================] - 26s 2s/step - loss: 2.8209 - accuracy: 0.3734 - val_loss: 1.4658 - val_accuracy: 0.2692 - lr: 0.0100
# Epoch 2/300
# 10/10 [==============================] - 13s 1s/step - loss: 1.9845 - accuracy: 0.2911 - val_loss: 1.3118 - val_accuracy: 0.0769 - lr: 0.0100
# Epoch 3/300
# 10/10 [==============================] - 13s 1s/step - loss: 1.5637 - accuracy: 0.5127 - val_loss: 8.1499 - val_accuracy: 0.0769 - lr: 0.0100
# Epoch 4/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.4708 - accuracy: 0.6329 - val_loss: 11.2335 - val_accuracy: 0.0962 - lr: 0.0100
# Epoch 5/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.1080 - accuracy: 0.7152 - val_loss: 11.4601 - val_accuracy: 0.0769 - lr: 0.0100
# Epoch 6/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.9644 - accuracy: 0.7152 - val_loss: 196.7511 - val_accuracy: 0.0769 - lr: 0.0100
# Epoch 7/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.9102 - accuracy: 0.7152 - val_loss: 494.5233 - val_accuracy: 0.0769 - lr: 0.0100
# Epoch 8/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.9818 - accuracy: 0.7595 - val_loss: 20.7619 - val_accuracy: 0.1154 - lr: 0.0050
# Epoch 9/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.9887 - accuracy: 0.7975 - val_loss: 22.3611 - val_accuracy: 0.1923 - lr: 0.0050
# Epoch 10/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.7391 - accuracy: 0.8987 - val_loss: 8.3992 - val_accuracy: 0.5000 - lr: 0.0050
# Epoch 11/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.3791 - accuracy: 0.8734 - val_loss: 15.6310 - val_accuracy: 0.6538 - lr: 0.0050
# Epoch 12/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.4608 - accuracy: 0.8797 - val_loss: 5.4698 - val_accuracy: 0.6538 - lr: 0.0050
# Epoch 13/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.3752 - accuracy: 0.8924 - val_loss: 3.8531 - val_accuracy: 0.5000 - lr: 0.0025
# Epoch 14/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.2034 - accuracy: 0.9494 - val_loss: 3.0095 - val_accuracy: 0.6538 - lr: 0.0025
# Epoch 15/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.1612 - accuracy: 0.9620 - val_loss: 2.6613 - val_accuracy: 0.7115 - lr: 0.0025
# Epoch 16/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.1415 - accuracy: 0.9684 - val_loss: 2.5653 - val_accuracy: 0.7308 - lr: 0.0025
# Epoch 17/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0914 - accuracy: 0.9684 - val_loss: 3.0395 - val_accuracy: 0.7115 - lr: 0.0025
# Epoch 18/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0401 - accuracy: 0.9937 - val_loss: 2.8902 - val_accuracy: 0.6923 - lr: 0.0012
# Epoch 19/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0606 - accuracy: 0.9873 - val_loss: 1.9672 - val_accuracy: 0.7692 - lr: 0.0012
# Epoch 20/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 1.8130 - val_accuracy: 0.8269 - lr: 0.0012
# Epoch 21/300
# 10/10 [==============================] - 11s 1s/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 1.8133 - val_accuracy: 0.7692 - lr: 0.0012
# Epoch 22/300
# 10/10 [==============================] - 11s 1s/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 1.8329 - val_accuracy: 0.7692 - lr: 0.0012
# ------------------------------------------------------------------------
# Score for fold 3: loss of 1.34; accuracy of 7.69%
# ------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 1.4 - Accuracy: 0.38%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 1.08 - Accuracy: 0.35%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 1.34 - Accuracy: 0.08%
# ------------------------------------------------------------------------
# Average scores for all folds (LR = 0.01, mtm = 0.9):
# > Accuracy: 0.27 (+- 0.14)
# > Loss: 1.27 (+- 0.14)
# ------------------------------------------------------------------------
#
#
# ------------------------------------------------------------------------
# Training for combination 4/9 ...
# Learning rate = 0.001
# Momentum = 0
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Training for fold 1/3 ...
# ------------------------------------------------------------------------
# [21, 60, 9, 48, 31, 16, 47, 51, 143, 69, 116, 83, 38, 67, 41, 11, 85, 144, 63, 156, 115, 126, 119, 153, 102, 113, 147, 106, 159, 7, 187, 185, 196, 186, 201, 206, 179, 175, 111, 164, 160, 182, 71, 138, 66, 50, 1, 205, 45, 53, 62, 105]
# Epoch 1/300
# 10/10 [==============================] - 24s 2s/step - loss: 1.8449 - accuracy: 0.3544 - val_loss: 1.3552 - val_accuracy: 0.1154 - lr: 0.0010
# Epoch 2/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.5781 - accuracy: 0.4810 - val_loss: 1.0989 - val_accuracy: 0.4615 - lr: 0.0010
# Epoch 3/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.3850 - accuracy: 0.6456 - val_loss: 1.0642 - val_accuracy: 0.5192 - lr: 0.0010
# Epoch 4/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.2231 - accuracy: 0.7405 - val_loss: 1.0895 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 5/300
# 10/10 [==============================] - 14s 1s/step - loss: 1.0313 - accuracy: 0.8228 - val_loss: 0.9136 - val_accuracy: 0.6346 - lr: 0.0010
# Epoch 6/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.9403 - accuracy: 0.8481 - val_loss: 0.9494 - val_accuracy: 0.6346 - lr: 0.0010
# Epoch 7/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.8221 - accuracy: 0.9051 - val_loss: 0.9184 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 8/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.7379 - accuracy: 0.9304 - val_loss: 0.8309 - val_accuracy: 0.6731 - lr: 0.0010
# Epoch 9/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.6579 - accuracy: 0.9494 - val_loss: 0.8445 - val_accuracy: 0.6731 - lr: 0.0010
# Epoch 10/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.5774 - accuracy: 0.9177 - val_loss: 0.8430 - val_accuracy: 0.6731 - lr: 0.0010
# Epoch 11/300
# 10/10 [==============================] - 15s 1s/step - loss: 0.5380 - accuracy: 0.9494 - val_loss: 0.7833 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 12/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.4825 - accuracy: 0.9620 - val_loss: 0.7674 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 13/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.4488 - accuracy: 0.9557 - val_loss: 0.7580 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 14/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.4084 - accuracy: 0.9620 - val_loss: 0.7429 - val_accuracy: 0.6731 - lr: 0.0010
# Epoch 15/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.3548 - accuracy: 0.9937 - val_loss: 0.7430 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 16/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.3508 - accuracy: 0.9810 - val_loss: 0.7274 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 17/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.2982 - accuracy: 0.9873 - val_loss: 0.7497 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 18/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.2584 - accuracy: 0.9873 - val_loss: 0.7445 - val_accuracy: 0.6731 - lr: 0.0010
# Epoch 19/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.2502 - accuracy: 0.9810 - val_loss: 0.7371 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 20/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.2144 - accuracy: 0.9873 - val_loss: 0.7154 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 21/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.1941 - accuracy: 0.9937 - val_loss: 0.7082 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 22/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.1750 - accuracy: 1.0000 - val_loss: 0.7053 - val_accuracy: 0.7115 - lr: 0.0010
# Epoch 23/300
# 10/10 [==============================] - 11s 1s/step - loss: 0.1423 - accuracy: 1.0000 - val_loss: 0.7120 - val_accuracy: 0.7115 - lr: 0.0010
# Epoch 24/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.1504 - accuracy: 1.0000 - val_loss: 0.7073 - val_accuracy: 0.7115 - lr: 0.0010
# Epoch 25/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.1299 - accuracy: 1.0000 - val_loss: 0.7210 - val_accuracy: 0.7115 - lr: 0.0010
# Epoch 26/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.1469 - accuracy: 1.0000 - val_loss: 0.7456 - val_accuracy: 0.7115 - lr: 0.0010
# Epoch 27/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.1123 - accuracy: 1.0000 - val_loss: 0.7290 - val_accuracy: 0.7115 - lr: 0.0010
# Epoch 28/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0971 - accuracy: 1.0000 - val_loss: 0.7290 - val_accuracy: 0.6923 - lr: 5.0000e-04
# Epoch 29/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0941 - accuracy: 1.0000 - val_loss: 0.7376 - val_accuracy: 0.7115 - lr: 5.0000e-04
# Epoch 30/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0934 - accuracy: 1.0000 - val_loss: 0.7434 - val_accuracy: 0.7115 - lr: 5.0000e-04
# Epoch 31/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0874 - accuracy: 1.0000 - val_loss: 0.7480 - val_accuracy: 0.7115 - lr: 5.0000e-04
# Epoch 32/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0878 - accuracy: 1.0000 - val_loss: 0.7472 - val_accuracy: 0.7115 - lr: 5.0000e-04
# Epoch 33/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0951 - accuracy: 1.0000 - val_loss: 0.7562 - val_accuracy: 0.7115 - lr: 2.5000e-04
# Epoch 34/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0875 - accuracy: 1.0000 - val_loss: 0.7569 - val_accuracy: 0.7115 - lr: 2.5000e-04
# Epoch 35/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0932 - accuracy: 1.0000 - val_loss: 0.7663 - val_accuracy: 0.7115 - lr: 2.5000e-04
# Epoch 36/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0841 - accuracy: 1.0000 - val_loss: 0.7678 - val_accuracy: 0.7115 - lr: 2.5000e-04
# Epoch 37/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0799 - accuracy: 1.0000 - val_loss: 0.7728 - val_accuracy: 0.7115 - lr: 2.5000e-04
# Epoch 38/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0759 - accuracy: 1.0000 - val_loss: 0.7738 - val_accuracy: 0.6923 - lr: 1.2500e-04
# Epoch 39/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0963 - accuracy: 1.0000 - val_loss: 0.7785 - val_accuracy: 0.6923 - lr: 1.2500e-04
# Epoch 40/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0767 - accuracy: 1.0000 - val_loss: 0.7779 - val_accuracy: 0.6923 - lr: 1.2500e-04
# Epoch 41/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0853 - accuracy: 1.0000 - val_loss: 0.7831 - val_accuracy: 0.6923 - lr: 1.2500e-04
# Epoch 42/300
# ...
# Epoch 10/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.5952 - accuracy: 0.9620 - val_loss: 0.9835 - val_accuracy: 0.5577 - lr: 1.0000e-04
# Epoch 11/300
# 10/10 [==============================] - 16s 2s/step - loss: 0.5351 - accuracy: 0.9620 - val_loss: 0.9431 - val_accuracy: 0.5769 - lr: 1.0000e-04
# Epoch 12/300
# 10/10 [==============================] - 15s 1s/step - loss: 0.4606 - accuracy: 0.9873 - val_loss: 0.8935 - val_accuracy: 0.5769 - lr: 1.0000e-04
# Epoch 13/300
# 10/10 [==============================] - 15s 1s/step - loss: 0.4377 - accuracy: 0.9747 - val_loss: 0.8816 - val_accuracy: 0.5577 - lr: 1.0000e-04
# Epoch 14/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.3830 - accuracy: 0.9873 - val_loss: 0.8936 - val_accuracy: 0.5769 - lr: 1.0000e-04
# Epoch 15/300
# 10/10 [==============================] - 16s 2s/step - loss: 0.3625 - accuracy: 0.9873 - val_loss: 0.8607 - val_accuracy: 0.5577 - lr: 1.0000e-04
# Epoch 16/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.3366 - accuracy: 0.9810 - val_loss: 0.8706 - val_accuracy: 0.5769 - lr: 1.0000e-04
# Epoch 17/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.2984 - accuracy: 0.9873 - val_loss: 0.8669 - val_accuracy: 0.5769 - lr: 1.0000e-04
# Epoch 18/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.2793 - accuracy: 0.9810 - val_loss: 0.8544 - val_accuracy: 0.6154 - lr: 1.0000e-04
# Epoch 19/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.2267 - accuracy: 1.0000 - val_loss: 0.8527 - val_accuracy: 0.6346 - lr: 1.0000e-04
# Epoch 20/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.2138 - accuracy: 1.0000 - val_loss: 0.8455 - val_accuracy: 0.6346 - lr: 1.0000e-04
# Epoch 21/300
# 10/10 [==============================] - 15s 1s/step - loss: 0.1996 - accuracy: 1.0000 - val_loss: 0.8662 - val_accuracy: 0.6154 - lr: 1.0000e-04
# Epoch 22/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1953 - accuracy: 0.9873 - val_loss: 0.8697 - val_accuracy: 0.5962 - lr: 1.0000e-04
# Epoch 23/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1591 - accuracy: 1.0000 - val_loss: 0.8524 - val_accuracy: 0.6538 - lr: 1.0000e-04
# Epoch 24/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1478 - accuracy: 1.0000 - val_loss: 0.8549 - val_accuracy: 0.6538 - lr: 1.0000e-04
# Epoch 25/300
# 10/10 [==============================] - 16s 2s/step - loss: 0.1471 - accuracy: 1.0000 - val_loss: 0.8336 - val_accuracy: 0.6346 - lr: 1.0000e-04
# Epoch 26/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1416 - accuracy: 1.0000 - val_loss: 0.8453 - val_accuracy: 0.6346 - lr: 1.0000e-04
# Epoch 27/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1141 - accuracy: 1.0000 - val_loss: 0.8516 - val_accuracy: 0.6346 - lr: 1.0000e-04
# Epoch 28/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1019 - accuracy: 1.0000 - val_loss: 0.8503 - val_accuracy: 0.6346 - lr: 1.0000e-04
# Epoch 29/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1117 - accuracy: 0.9937 - val_loss: 0.8488 - val_accuracy: 0.6154 - lr: 1.0000e-04
# Epoch 30/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0891 - accuracy: 1.0000 - val_loss: 0.8536 - val_accuracy: 0.6154 - lr: 1.0000e-04
# Epoch 31/300
# 10/10 [==============================] - 16s 2s/step - loss: 0.0801 - accuracy: 1.0000 - val_loss: 0.8540 - val_accuracy: 0.6346 - lr: 5.0000e-05
# Epoch 32/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0969 - accuracy: 1.0000 - val_loss: 0.8550 - val_accuracy: 0.6538 - lr: 5.0000e-05
# Epoch 33/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0847 - accuracy: 1.0000 - val_loss: 0.8553 - val_accuracy: 0.6538 - lr: 5.0000e-05
# Epoch 34/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0714 - accuracy: 1.0000 - val_loss: 0.8666 - val_accuracy: 0.6538 - lr: 5.0000e-05
# Epoch 35/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0817 - accuracy: 1.0000 - val_loss: 0.8649 - val_accuracy: 0.6538 - lr: 5.0000e-05
# Epoch 36/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0667 - accuracy: 1.0000 - val_loss: 0.8680 - val_accuracy: 0.6538 - lr: 2.5000e-05
# Epoch 37/300
# 10/10 [==============================] - 13s 1s/step - loss: 0.0655 - accuracy: 1.0000 - val_loss: 0.8700 - val_accuracy: 0.6731 - lr: 2.5000e-05
# Epoch 38/300
# 10/10 [==============================] - 12s 1s/step - loss: 0.0715 - accuracy: 1.0000 - val_loss: 0.8704 - val_accuracy: 0.6731 - lr: 2.5000e-05
# Epoch 39/300
# 10/10 [==============================] - 15s 1s/step - loss: 0.0758 - accuracy: 1.0000 - val_loss: 0.8704 - val_accuracy: 0.6731 - lr: 2.5000e-05
# Epoch 40/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0606 - accuracy: 1.0000 - val_loss: 0.8705 - val_accuracy: 0.6731 - lr: 2.5000e-05
# Epoch 41/300
# 10/10 [==============================] - 18s 2s/step - loss: 0.0608 - accuracy: 1.0000 - val_loss: 0.8710 - val_accuracy: 0.6538 - lr: 1.2500e-05
# Epoch 42/300
# 10/10 [==============================] - 16s 2s/step - loss: 0.0645 - accuracy: 1.0000 - val_loss: 0.8725 - val_accuracy: 0.6346 - lr: 1.2500e-05
# Epoch 43/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 0.8731 - val_accuracy: 0.6538 - lr: 1.2500e-05
# Epoch 44/300
# 10/10 [==============================] - 14s 2s/step - loss: 0.0651 - accuracy: 1.0000 - val_loss: 0.8740 - val_accuracy: 0.6538 - lr: 1.2500e-05
# Epoch 45/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0540 - accuracy: 1.0000 - val_loss: 0.8754 - val_accuracy: 0.6538 - lr: 1.2500e-05
# ------------------------------------------------------------------------
# Score for fold 2: loss of 0.69; accuracy of 75.0%
# ------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Training for fold 3/3 ...
# ------------------------------------------------------------------------
# [25, 60, 84, 152, 17, 120, 20, 136, 2, 51, 103, 21, 148, 131, 143, 37, 89, 83, 33, 151, 104, 29, 11, 86, 32, 106, 16, 41, 185, 187, 7, 5, 62, 181, 3, 182, 161, 4, 192, 127, 194, 45, 179, 24, 70, 195, 193, 97, 155, 164, 40, 101]
# Epoch 1/300
# 10/10 [==============================] - 26s 2s/step - loss: 1.8154 - accuracy: 0.3101 - val_loss: 1.3239 - val_accuracy: 0.1346 - lr: 1.0000e-04
# Epoch 2/300
# 10/10 [==============================] - 16s 2s/step - loss: 1.6688 - accuracy: 0.3734 - val_loss: 1.2684 - val_accuracy: 0.1923 - lr: 1.0000e-04
# Epoch 3/300
# 10/10 [==============================] - 15s 2s/step - loss: 1.4081 - accuracy: 0.6076 - val_loss: 1.1173 - val_accuracy: 0.4231 - lr: 1.0000e-04
# Epoch 4/300
# 10/10 [==============================] - 16s 2s/step - loss: 1.2585 - accuracy: 0.7532 - val_loss: 1.0917 - val_accuracy: 0.4808 - lr: 1.0000e-04
# Epoch 5/300
# 10/10 [==============================] - 15s 2s/step - loss: 1.1012 - accuracy: 0.7785 - val_loss: 0.9949 - val_accuracy: 0.5769 - lr: 1.0000e-04
# Epoch 6/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.9626 - accuracy: 0.8101 - val_loss: 0.9265 - val_accuracy: 0.5962 - lr: 1.0000e-04
# Epoch 7/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.8774 - accuracy: 0.9051 - val_loss: 0.8781 - val_accuracy: 0.5962 - lr: 1.0000e-04
# Epoch 8/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.8133 - accuracy: 0.8544 - val_loss: 0.9299 - val_accuracy: 0.6154 - lr: 1.0000e-04
# Epoch 9/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.6866 - accuracy: 0.8987 - val_loss: 0.8366 - val_accuracy: 0.6731 - lr: 1.0000e-04
# Epoch 10/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.6264 - accuracy: 0.9430 - val_loss: 0.8155 - val_accuracy: 0.6731 - lr: 1.0000e-04
# Epoch 11/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.5635 - accuracy: 0.9367 - val_loss: 0.7968 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 12/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.5024 - accuracy: 0.9494 - val_loss: 0.7911 - val_accuracy: 0.6731 - lr: 1.0000e-04
# Epoch 13/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.4549 - accuracy: 0.9557 - val_loss: 0.7711 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 14/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.4153 - accuracy: 0.9873 - val_loss: 0.7570 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 15/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.3650 - accuracy: 0.9873 - val_loss: 0.7494 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 16/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.3409 - accuracy: 0.9873 - val_loss: 0.7354 - val_accuracy: 0.6731 - lr: 1.0000e-04
# Epoch 17/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.3288 - accuracy: 0.9747 - val_loss: 0.7318 - val_accuracy: 0.7115 - lr: 1.0000e-04
# Epoch 18/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.2848 - accuracy: 1.0000 - val_loss: 0.7193 - val_accuracy: 0.6731 - lr: 1.0000e-04
# Epoch 19/300
# 10/10 [==============================] - 16s 2s/step - loss: 0.2724 - accuracy: 0.9873 - val_loss: 0.7211 - val_accuracy: 0.7115 - lr: 1.0000e-04
# Epoch 20/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.2592 - accuracy: 0.9937 - val_loss: 0.7007 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 21/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.2205 - accuracy: 0.9873 - val_loss: 0.6902 - val_accuracy: 0.6731 - lr: 1.0000e-04
# Epoch 22/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.2007 - accuracy: 1.0000 - val_loss: 0.6978 - val_accuracy: 0.7115 - lr: 1.0000e-04
# Epoch 23/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1982 - accuracy: 1.0000 - val_loss: 0.6843 - val_accuracy: 0.7115 - lr: 1.0000e-04
# Epoch 24/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1862 - accuracy: 1.0000 - val_loss: 0.6790 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 25/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1507 - accuracy: 1.0000 - val_loss: 0.6797 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 26/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1426 - accuracy: 1.0000 - val_loss: 0.6700 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 27/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.1376 - accuracy: 1.0000 - val_loss: 0.6644 - val_accuracy: 0.6731 - lr: 1.0000e-04
# Epoch 28/300
# 10/10 [==============================] - 16s 2s/step - loss: 0.1281 - accuracy: 1.0000 - val_loss: 0.6660 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 29/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.1358 - accuracy: 1.0000 - val_loss: 0.6601 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 30/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1042 - accuracy: 1.0000 - val_loss: 0.6586 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 31/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.1308 - accuracy: 0.9937 - val_loss: 0.6592 - val_accuracy: 0.7115 - lr: 1.0000e-04
# Epoch 32/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0988 - accuracy: 1.0000 - val_loss: 0.6550 - val_accuracy: 0.7115 - lr: 1.0000e-04
# Epoch 33/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0970 - accuracy: 1.0000 - val_loss: 0.6543 - val_accuracy: 0.7115 - lr: 1.0000e-04
# Epoch 34/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0762 - accuracy: 1.0000 - val_loss: 0.6533 - val_accuracy: 0.7115 - lr: 1.0000e-04
# Epoch 35/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0865 - accuracy: 1.0000 - val_loss: 0.6532 - val_accuracy: 0.7115 - lr: 1.0000e-04
# Epoch 36/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0699 - accuracy: 1.0000 - val_loss: 0.6592 - val_accuracy: 0.7115 - lr: 1.0000e-04
# Epoch 37/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0661 - accuracy: 1.0000 - val_loss: 0.6566 - val_accuracy: 0.7308 - lr: 1.0000e-04
# Epoch 38/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0651 - accuracy: 1.0000 - val_loss: 0.6580 - val_accuracy: 0.7308 - lr: 1.0000e-04
# Epoch 39/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0588 - accuracy: 1.0000 - val_loss: 0.6560 - val_accuracy: 0.7115 - lr: 1.0000e-04
# Epoch 40/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0569 - accuracy: 1.0000 - val_loss: 0.6573 - val_accuracy: 0.7115 - lr: 5.0000e-05
# Epoch 41/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.6574 - val_accuracy: 0.7115 - lr: 5.0000e-05
# Epoch 42/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0564 - accuracy: 1.0000 - val_loss: 0.6582 - val_accuracy: 0.7115 - lr: 5.0000e-05
# Epoch 43/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 0.6585 - val_accuracy: 0.7308 - lr: 5.0000e-05
# Epoch 44/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0428 - accuracy: 1.0000 - val_loss: 0.6597 - val_accuracy: 0.7308 - lr: 5.0000e-05
# Epoch 45/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0551 - accuracy: 1.0000 - val_loss: 0.6603 - val_accuracy: 0.7308 - lr: 2.5000e-05
# Epoch 46/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0447 - accuracy: 1.0000 - val_loss: 0.6606 - val_accuracy: 0.7308 - lr: 2.5000e-05
# Epoch 47/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0474 - accuracy: 1.0000 - val_loss: 0.6609 - val_accuracy: 0.7308 - lr: 2.5000e-05
# Epoch 48/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.6609 - val_accuracy: 0.7308 - lr: 2.5000e-05
# Epoch 49/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0401 - accuracy: 1.0000 - val_loss: 0.6612 - val_accuracy: 0.7308 - lr: 2.5000e-05
# Epoch 50/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0446 - accuracy: 1.0000 - val_loss: 0.6615 - val_accuracy: 0.7308 - lr: 1.2500e-05
# Epoch 51/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0450 - accuracy: 1.0000 - val_loss: 0.6616 - val_accuracy: 0.7308 - lr: 1.2500e-05
# Epoch 52/300
# 10/10 [==============================] - 14s 1s/step - loss: 0.0462 - accuracy: 1.0000 - val_loss: 0.6622 - val_accuracy: 0.7308 - lr: 1.2500e-05
# Epoch 53/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0416 - accuracy: 1.0000 - val_loss: 0.6624 - val_accuracy: 0.7308 - lr: 1.2500e-05
# Epoch 54/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 0.6626 - val_accuracy: 0.7115 - lr: 1.2500e-05
# Epoch 55/300
# 10/10 [==============================] - 15s 2s/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.6631 - val_accuracy: 0.7115 - lr: 6.2500e-06
# ------------------------------------------------------------------------
# Score for fold 3: loss of 0.76; accuracy of 67.31%
# ------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.73 - Accuracy: 0.69%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.69 - Accuracy: 0.75%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.76 - Accuracy: 0.67%
# ------------------------------------------------------------------------
# Average scores for all folds (LR = 0.0001, mtm = 0.9):
# > Accuracy: 0.71 (+- 0.03)
# > Loss: 0.73 (+- 0.03)
# ------------------------------------------------------------------------

# %%
def plot_metrics(history):
    """
    Function that plots the metrics from the training process
        - history is the output from the training process
    """
    fig = plt.figure(figsize = (15, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc = 'upper left')
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc = 'upper right')
    
    plt.show()
    return

def print_cm(cm, labels, hide_zeroes=False, hide_diagonal=False, hide_threshold=None):
    """
    Credit to:
    https://gist.github.com/zachguo/10296432
    
    Function that makes a pretty print for confusion matrixes
        - cm is the array of histories generated during the training process
        - labels is number of epochs fixed for the training process
        - hide_zeroes is a boolean that allows the user to hide the zeroes in the matrix
        - hide_diagonal is a boolean that allows the user to hide the diagonal in the matrix
        - hide_threshold is a number that allows the user to hide results in the matrix below that value
    """
    columnwidth = max([len(x) for x in labels] + [5])  # 5 is value length
    empty_cell = " " * columnwidth
    # Print header
    print("    " + empty_cell, end=" ")
    for label in labels:
        print("%{0}s".format(columnwidth) % label, end=" ")
    print()
    # Print rows
    for i, label1 in enumerate(labels):
        print("    %{0}s".format(columnwidth) % label1, end=" ")
        for j in range(len(labels)):
            cell = "%{0}.1f".format(columnwidth) % cm[i, j]
            if hide_zeroes:
                cell = cell if float(cm[i, j]) != 0 else empty_cell
            if hide_diagonal:
                cell = cell if i != j else empty_cell
            if hide_threshold:
                cell = cell if cm[i, j] > hide_threshold else empty_cell
            print(cell, end=" ")
        print()
    return

# %%
print(f'Resultados promedios del entrenamiento DenseNet-{vista}:')
for i in range(len(glob_param)):
    print(f'- LR={glob_param[i, 0]} / mom={glob_param[i, 1]}:\tAcc={round(np.mean(scores_glob_array[i, :, 1]), 2)} (+- {round(np.std(scores_glob_array[i, :, 1]), 2)}) - Loss={round(np.mean(scores_glob_array[i, :, 0]), 2)} (+- {round(np.std(scores_glob_array[i, :, 0]), 2)})')

idx_best = np.argmax(np.mean(scores_glob_array, 1)[:, 1])
history_best = history_list[idx_best]
model_best = history_best.model
print(f'\nEl mejor resultado para la DenseNet-{vista} se obtiene para LR = {glob_param[idx_best, 0]} y momentum = {glob_param[idx_best, 1]}.')
# Out:
# Resultados promedios del entrenamiento DenseNet-CC:
# - LR=0.01 / mom=0.0:	Acc=0.65 (+- 0.02) - Loss=0.83 (+- 0.01)
# - LR=0.01 / mom=0.5:	Acc=0.65 (+- 0.01) - Loss=0.81 (+- 0.02)
# - LR=0.01 / mom=0.9:	Acc=0.27 (+- 0.14) - Loss=1.27 (+- 0.14)
# - LR=0.001 / mom=0.0:	Acc=0.7 (+- 0.05) - Loss=0.73 (+- 0.04)
# - LR=0.001 / mom=0.5:	Acc=0.67 (+- 0.05) - Loss=0.78 (+- 0.06)
# - LR=0.001 / mom=0.9:	Acc=0.71 (+- 0.02) - Loss=0.74 (+- 0.07)
# - LR=0.0001 / mom=0.0:	Acc=0.69 (+- 0.04) - Loss=0.74 (+- 0.02)
# - LR=0.0001 / mom=0.5:	Acc=0.68 (+- 0.04) - Loss=0.73 (+- 0.02)
# - LR=0.0001 / mom=0.9:	Acc=0.71 (+- 0.03) - Loss=0.73 (+- 0.03)
#
# El mejor resultado para la DenseNet-CC se obtiene para LR = 0.001 y momentum = 0.9.

# %%
plot_metrics(history_best)

# %%
conf_matrix = metrics.confusion_matrix(Y_val.argmax(axis = 1), model_best.predict(X_val).argmax(axis = 1))
print_cm(conf_matrix, list(dict_valores.keys()))
# Out:
# 2/2 [==============================] - 4s 897ms/step
#                     benigno seguimiento     maligno
#         benigno        27.0         0.0         1.0
#     seguimiento         3.0         0.0         1.0
#         maligno         9.0         0.0        11.0

# %%
classif_report = metrics.classification_report(Y_val.argmax(axis = 1), model_best.predict(X_val).argmax(axis = 1),
                                               target_names = list(dict_valores.keys()))
print(classif_report)
# Out:
# 2/2 [==============================] - 2s 974ms/step
#               precision    recall  f1-score   support
#
#      benigno       0.69      0.96      0.81        28
#  seguimiento       0.00      0.00      0.00         4
#      maligno       0.85      0.55      0.67        20
#
#     accuracy                           0.73        52
#    macro avg       0.51      0.50      0.49        52
# weighted avg       0.70      0.73      0.69        52
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
file_path = './model_best_DN169_ft_' + vista
K.models.save_model(model_best, file_path)
# Out:
# INFO:tensorflow:Assets written to: ./model_best_DN169_ft_CC/assets
# INFO:tensorflow:Assets written to: ./model_best_DN169_ft_CC/assets
